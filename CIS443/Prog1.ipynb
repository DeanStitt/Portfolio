# %% [markdown]
# # CIS 443-01 - Analytics Programming
# ## Program 1
# __Grading ID__: D8801(double click the cell in Jupyter to edit)<br>
# __Due__: Wednesday, September 9 (by 11:59 PM)<br />
# __Worth__: 50 pts.<br />
# __Purpose__: Use repetition control structure and accumulator pattern to estimate value of π.

# %% [markdown]
# ### Directions
# In the code cell below, write Python code to accomplish the following using what you've learned through Chapter 3. Complete Exercise 3.14 from p. 114.
#
# Write your solution to allow the user to enter a value for the number of terms that they want the code to run for in the approximation calculation. Output the estimate after each term is added in a tabular format, using f-strings, field width, and right-alignment. Print the term number in a field with width of 8 and the estimate of π in a field with width of 10 and 6 digits after the decimal. (45 pts.)
#
# Use your code to answer the questions cells below. (5 pts.)
#
# I suggest that you develop your solution in steps. You must alternate between subtraction and addition on each term (or, use addition with a coefficient that alternates from -1 to +1 on each term), so you might start with that. The denominator is going up by 2s each term, so 3, 5, 7, etc., so maybe get that working next. Once you have all the pieces working, then you put it together in a summation (that starts from 4 instead of 0 for this series).
#
# If you prefer, you may submit a Python script instead (_Prog1.py_) of a notebook but remember to answer the questions below by including them in comments at end of script if you choose this route.
#
# If you wish to incorporate a little of Chapter 4, put the code for the estimation in a method named _pi_estimator_ that accepts number of terms as a parameter.

# %%
"""Calculate Pi using user input"""
pi = 0.0
sign = 1
num_pass = 0
number = 1
denom = 1.0
user_value = int(input("Enter number of terms to evaluate **200,000 will evaluate all questions, Uncomment to see all progression** "))
user_value += 1
for i in range(1, user_value):
    num_pass += 1
    pi = pi +(sign * (4/(denom)))
    sign = sign * -1
    #print (f'Pass {num_pass} = {pi:>10.6f}')
    #print (f'4/{denom}')
    denom +=(number +1)
    if (round(pi, 5)== 3.14159):
        print (f' To get to 3.14159 = {num_pass:>8}')
        break
pi = 0.0
sign = 1
num_pass = 0
number = 1
denom = 1.0
for i in range(1, user_value):
    num_pass += 1
    pi = pi +(sign * (4/(denom)))
    sign = sign * -1
    #print (f'Pass {num_pass} = {pi:>10.6f}')
    #print (f'4/{denom}')
    denom +=(number +1)                   
    if (round(pi, 4) == 3.1415):
        print (f' To get to 3.1415 = {num_pass:>8}')
        break
pi = 0.0
sign = 1
num_pass = 0
number = 1
denom = 1.0
for i in range(1, user_value):
    num_pass += 1
    pi = pi +(sign * (4/(denom)))
    sign = sign * -1
    #print (f'Pass {num_pass} = {pi:>10.6f}')
    #print (f'4/{denom}')
    denom +=(number +1)
    if (round(pi, 3) == 3.141):
        print (f' To get to 3.141 = {num_pass:>8}')
        break
pi = 0.0
sign = 1
num_pass = 0
number = 1
denom = 1.0
for i in range(1, user_value):
    num_pass += 1
    pi = pi +(sign * (4/(denom)))
    sign = sign * -1
    print (f'Pass {num_pass} = {pi:>10.6f}')
    #print (f'4/{denom}')
    denom +=(number +1)
    if (round(pi, 2) == 3.14):
        print (f' To get to 3.14 = {num_pass:>8}')
        break
print('done')
# Out:
# Enter number of terms to evaluate **200,000 will evaluate all questions, Uncomment to see all progression**  200000
#  To get to 3.14159 =   130658
#  To get to 3.1415 =     7010
#  To get to 3.141 =      916
# Pass 1 =   4.000000
# Pass 2 =   2.666667
# Pass 3 =   3.466667
# Pass 4 =   2.895238
# Pass 5 =   3.339683
# Pass 6 =   2.976046
# Pass 7 =   3.283738
# Pass 8 =   3.017072
# Pass 9 =   3.252366
# Pass 10 =   3.041840
# Pass 11 =   3.232316
# Pass 12 =   3.058403
# Pass 13 =   3.218403
# Pass 14 =   3.070255
# Pass 15 =   3.208186
# Pass 16 =   3.079153
# Pass 17 =   3.200366
# Pass 18 =   3.086080
# Pass 19 =   3.194188
# Pass 20 =   3.091624
# Pass 21 =   3.189185
# Pass 22 =   3.096162
# Pass 23 =   3.185050
# Pass 24 =   3.099944
# Pass 25 =   3.181577
# Pass 26 =   3.103145
# Pass 27 =   3.178617
# Pass 28 =   3.105890
# Pass 29 =   3.176065
# Pass 30 =   3.108269
# Pass 31 =   3.173842
# Pass 32 =   3.110350
# Pass 33 =   3.171889
# Pass 34 =   3.112187
# Pass 35 =   3.170158
# Pass 36 =   3.113820
# Pass 37 =   3.168615
# Pass 38 =   3.115281
# Pass 39 =   3.167229
# Pass 40 =   3.116597
# Pass 41 =   3.165979
# Pass 42 =   3.117787
# Pass 43 =   3.164845
# Pass 44 =   3.118868
# Pass 45 =   3.163812
# Pass 46 =   3.119856
# Pass 47 =   3.162867
# Pass 48 =   3.120762
# Pass 49 =   3.161999
# Pass 50 =   3.121595
# Pass 51 =   3.161199
# Pass 52 =   3.122364
# Pass 53 =   3.160459
# Pass 54 =   3.123076
# Pass 55 =   3.159773
# Pass 56 =   3.123737
# Pass 57 =   3.159135
# Pass 58 =   3.124353
# Pass 59 =   3.158541
# Pass 60 =   3.124927
# Pass 61 =   3.157985
# Pass 62 =   3.125465
# Pass 63 =   3.157465
# Pass 64 =   3.125969
# Pass 65 =   3.156976
# Pass 66 =   3.126442
# Pass 67 =   3.156517
# Pass 68 =   3.126888
# Pass 69 =   3.156085
# Pass 70 =   3.127308
# Pass 71 =   3.155676
# Pass 72 =   3.127704
# Pass 73 =   3.155291
# Pass 74 =   3.128080
# Pass 75 =   3.154925
# Pass 76 =   3.128435
# Pass 77 =   3.154579
# Pass 78 =   3.128773
# Pass 79 =   3.154250
# Pass 80 =   3.129093
# Pass 81 =   3.153938
# Pass 82 =   3.129398
# Pass 83 =   3.153640
# Pass 84 =   3.129688
# Pass 85 =   3.153357
# Pass 86 =   3.129965
# Pass 87 =   3.153087
# Pass 88 =   3.130229
# Pass 89 =   3.152828
# Pass 90 =   3.130482
# Pass 91 =   3.152581
# Pass 92 =   3.130723
# Pass 93 =   3.152345
# Pass 94 =   3.130955
# Pass 95 =   3.152119
# Pass 96 =   3.131176
# Pass 97 =   3.151902
# Pass 98 =   3.131389
# Pass 99 =   3.151693
# Pass 100 =   3.131593
# Pass 101 =   3.151493
# Pass 102 =   3.131789
# Pass 103 =   3.151301
# Pass 104 =   3.131977
# Pass 105 =   3.151116
# Pass 106 =   3.132159
# Pass 107 =   3.150938
# Pass 108 =   3.132334
# Pass 109 =   3.150767
# Pass 110 =   3.132502
# Pass 111 =   3.150601
# Pass 112 =   3.132664
# Pass 113 =   3.150442
# Pass 114 =   3.132821
# Pass 115 =   3.150288
# Pass 116 =   3.132972
# Pass 117 =   3.150140
# Pass 118 =   3.133118
# Pass 119 =   3.149996
# Pass 120 =   3.133259
# Pass 121 =   3.149857
# Pass 122 =   3.133396
# Pass 123 =   3.149723
# Pass 124 =   3.133528
# Pass 125 =   3.149593
# Pass 126 =   3.133656
# Pass 127 =   3.149467
# Pass 128 =   3.133780
# Pass 129 =   3.149344
# Pass 130 =   3.133900
# Pass 131 =   3.149226
# Pass 132 =   3.134017
# Pass 133 =   3.149111
# Pass 134 =   3.134130
# Pass 135 =   3.149000
# Pass 136 =   3.134240
# Pass 137 =   3.148892
# Pass 138 =   3.134346
# Pass 139 =   3.148787
# Pass 140 =   3.134450
# Pass 141 =   3.148685
# Pass 142 =   3.134550
# Pass 143 =   3.148586
# Pass 144 =   3.134648
# Pass 145 =   3.148489
# Pass 146 =   3.134743
# Pass 147 =   3.148395
# Pass 148 =   3.134836
# Pass 149 =   3.148304
# Pass 150 =   3.134926
# Pass 151 =   3.148215
# Pass 152 =   3.135014
#  To get to 3.14 =      152
# done

# %% [markdown]
# How many terms of this series do you have to use before you first get 3.14?<br />
# XX<br />
# 3.141?<br />
# XX<br />
# 3.1415?<br />
# XX<br />
# 3.14159?<br />
# XX<br />
# Double click the cell in Jupyter to edit (5 pts.)

# %% [markdown]
# Be sure to save and exit your Jupyter Notebook and Shutdown Jupyter Lab (from the __File__ menu) before you submit your notebook on Blackboard for grading.
